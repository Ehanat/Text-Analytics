# %% [markdown]
# ## Group mumbers
# * Errenbai Yeerhanti (SW01081538)
# * Zulfadhli Fakhri bin Johan (SW01081044)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import csv

custom_headers = {
    "accept-language": "en-GB,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Cache-Control": "max-age=0",
    "Connection": "keep-alive",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36",
}

# initialize the reviews list
reviews = []

# first page url
root_url = 'https://www.amazon.com/OneGame-Ergonomic-Adjustable-Backrest-Blackgray/product-reviews/B0CNZ287Y1/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&pageNumber=1&reviewerType=all_reviews'

# %%
# get the soup base on the url
def get_soup(url):
    response = requests.get(url, headers=custom_headers)
    if response.status_code != 200:
        print("Error in getting webpage")
        exit(-1)
    soup = BeautifulSoup(response.text, "lxml")
    return soup

# %%
# use re libiray to get the date from the string
def get_date(text):
    pattern = r'on\s([A-Za-z]+\s\d{1,2},\s\d{4})'
    match = re.search(pattern, text)
    return match.group(1)

# %%
# store single page reviews to the reviews list
def get_onepage(soup, reviews):
    review_elements = soup.find_all('div', class_='a-section review aok-relative')
    for review in review_elements:
        username = review.find('div', class_='a-profile-content').text
        date_text = review.find('span', class_='a-size-base a-color-secondary review-date').text
        date = get_date(date_text)
        review_text = review.find('div', class_='a-row a-spacing-small review-data').text
        reviews.append({'username': username, 'date': date, 'review': review_text})

# %%
# get the multiple page reviews
def get_multiple_page(url):    
    for page in range(1, 6):
        soup = get_soup(root_url)
        get_onepage(soup, reviews)
        li = soup.find('li', class_='a-last')
        url = li.find('a')['href']
        print(len(reviews))
        time.sleep(1)
        print(f'page {page} ...')

# %%
get_multiple_page(root_url)
# Out:
# 10
# page 1 ...
# 20
# page 2 ...
# 30
# page 3 ...
# 40
# page 4 ...
# 50
# page 5 ...

# %%
# write data to the csv file from the reviews list
with open('amazon_reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=['username', 'date', 'review'])
    writer.writeheader()
    writer.writerows(reviews)

# %%
df = pd.read_csv('amazon_reviews.csv')
df
# Out:
#         username               date  \
# 0           bing     March 14, 2024
# 1         Quinci     March 13, 2024
# 2             JZ      March 1, 2024
# 3     Stephanie      March 15, 2024
# 4   Sherry Dallo      March 2, 2024
# 5          WENDY      March 1, 2024
# 6      Travis L.     March 11, 2024
# 7           kiwi     March 11, 2024
# 8         Lau C.      March 5, 2024
# 9         yalch⭐  February 13, 2024
# 10          bing     March 14, 2024
# 11        Quinci     March 13, 2024
# 12            JZ      March 1, 2024
# 13    Stephanie      March 15, 2024
# 14  Sherry Dallo      March 2, 2024
# 15         WENDY      March 1, 2024
# 16     Travis L.     March 11, 2024
# 17          kiwi     March 11, 2024
# 18        Lau C.      March 5, 2024
# 19        yalch⭐  February 13, 2024
# 20          bing     March 14, 2024
# 21        Quinci     March 13, 2024
# 22            JZ      March 1, 2024
# 23    Stephanie      March 15, 2024
# 24  Sherry Dallo      March 2, 2024
# 25         WENDY      March 1, 2024
# 26     Travis L.     March 11, 2024
# 27          kiwi     March 11, 2024
# 28        Lau C.      March 5, 2024
# 29        yalch⭐  February 13, 2024
# 30          bing     March 14, 2024
# 31        Quinci     March 13, 2024
# 32            JZ      March 1, 2024
# 33    Stephanie      March 15, 2024
# 34  Sherry Dallo      March 2, 2024
# 35         WENDY      March 1, 2024
# 36     Travis L.     March 11, 2024
# 37          kiwi     March 11, 2024
# 38        Lau C.      March 5, 2024
# 39        yalch⭐  February 13, 2024
# 40          bing     March 14, 2024
# 41        Quinci     March 13, 2024
# 42            JZ      March 1, 2024
# 43    Stephanie      March 15, 2024
# 44  Sherry Dallo      March 2, 2024
# 45         WENDY      March 1, 2024
# 46     Travis L.     March 11, 2024
# 47          kiwi     March 11, 2024
# 48        Lau C.      March 5, 2024
# 49        yalch⭐  February 13, 2024
#
#                                                review
# 0   \nI just bought the Onegame gaming chair with ...
# 1   \nThis is a very solid option for affordable g...
# 2   \nMy son really likes his new gaming chair.  T...
# 3   \nMy rating is for the instructions that are h...
# 4   \nThe chairs are great! My husband likes it ve...
# 5   \nThe chair is very comfortable. I especially ...
# 6   \nI think looks and functionality it's a 10/10...
# 7   \nThe quality is very good, very easy to insta...
# 8   \nThe chair’s manual was short and easy to und...
# 9   \nFirst of all, for this price, no way you are...
# 10  \nI just bought the Onegame gaming chair with ...
# 11  \nThis is a very solid option for affordable g...
# 12  \nMy son really likes his new gaming chair.  T...
# 13  \nMy rating is for the instructions that are h...
# 14  \nThe chairs are great! My husband likes it ve...
# 15  \nThe chair is very comfortable. I especially ...
# 16  \nI think looks and functionality it's a 10/10...
# 17  \nThe quality is very good, very easy to insta...
# 18  \nThe chair’s manual was short and easy to und...
# 19  \nFirst of all, for this price, no way you are...
# 20  \nI just bought the Onegame gaming chair with ...
# 21  \nThis is a very solid option for affordable g...
# 22  \nMy son really likes his new gaming chair.  T...
# 23  \nMy rating is for the instructions that are h...
# 24  \nThe chairs are great! My husband likes it ve...
# 25  \nThe chair is very comfortable. I especially ...
# 26  \nI think looks and functionality it's a 10/10...
# 27  \nThe quality is very good, very easy to insta...
# 28  \nThe chair’s manual was short and easy to und...
# 29  \nFirst of all, for this price, no way you are...
# 30  \nI just bought the Onegame gaming chair with ...
# 31  \nThis is a very solid option for affordable g...
# 32  \nMy son really likes his new gaming chair.  T...
# 33  \nMy rating is for the instructions that are h...
# 34  \nThe chairs are great! My husband likes it ve...
# 35  \nThe chair is very comfortable. I especially ...
# 36  \nI think looks and functionality it's a 10/10...
# 37  \nThe quality is very good, very easy to insta...
# 38  \nThe chair’s manual was short and easy to und...
# 39  \nFirst of all, for this price, no way you are...
# 40  \nI just bought the Onegame gaming chair with ...
# 41  \nThis is a very solid option for affordable g...
# 42  \nMy son really likes his new gaming chair.  T...
# 43  \nMy rating is for the instructions that are h...
# 44  \nThe chairs are great! My husband likes it ve...
# 45  \nThe chair is very comfortable. I especially ...
# 46  \nI think looks and functionality it's a 10/10...
# 47  \nThe quality is very good, very easy to insta...
# 48  \nThe chair’s manual was short and easy to und...
# 49  \nFirst of all, for this price, no way you are...

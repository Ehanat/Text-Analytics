# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import re
from datetime import datetime

# %%
url = 'https://shopee.com.my/Xiaomi-Redmi-TWS-Bluetooth-Earphone-Wireless-Headphones-Stereo-Earbuds-Sport-Headset-Hifi-Bass-Waterproof-Noise-Reduction-HD-Mic-i.661976240.18954757803?sp_atk=cb4cd446-d34d-401e-a0f1-3c5a3db4e1c7&xptdk=cb4cd446-d34d-401e-a0f1-3c5a3db4e1c7&is_from_login=true'
r = re.search(r'i\.(\d+)\.(\d+)', url)
if r:
    shop_id, item_id = r.group(1), r.group(2)
else:
    print("Invalid URL")
    exit()

# %%
offset = 0
reviews = []
page_count = 1
while page_count < 10:
    ratings_url = f'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
    data = requests.get(ratings_url).json()

    for rating in data['data']['ratings']:
        date = datetime.fromtimestamp(rating['ctime'])
        username = rating['author_username']
        comment = rating['comment']
        reviews.append({'username': username, 'comment': comment, 'date': date})

    offset += 10
    page_count += 1

# %%
print(reviews)
# Out:
# [{'username': 'f*****9', 'comment': 'Quality:extraordinary\n\nFirst try sudah memang bagus bunyi dia. Bass dia pun best la. Excited sangat dah ni nak guna time kerja. Tak lah bosan sangat kat ofis kn. Boleh try beli la', 'date': datetime.datetime(2023, 11, 24, 8, 35, 5)}, {'username': 'd*****n', 'comment': 'Performance:long lasting battery,\nQuality:nice\n\nDelivery within a week, so ok la kan..sangat senang nak connect, bateri tahan lama, dia tak la sensitif sgt so , pusing atas katil kiri kanan ke, kena anak tudung ke takpe sebb x cepat disconnected, melekat kat telinga pun nice je, bass and sound dia surprisingly very good utk harga less than rm10...cuma packaging je risau takde kotak😂', 'date': datetime.datetime(2024, 1, 9, 11, 48, 24)}, {'username': 'hafizaiman123', 'comment': 'Performance:nice wajib beli\nQuality:quality nice. x ringan mcm yg harga kat tt shop tu. yg ni nmpk la quality tu pegang pun dah tahu\n\nKalau nk beli untuk buat kerja sambil layan lagu baik beli yg ni. Bass dia pun ok. Bateri tahan lama', 'date': datetime.datetime(2023, 12, 17, 14, 22, 32)}, {'username': 'andy_dino', 'comment': "Performance:Not bad at all.\nQuality:Quite Good, I'm impressed.\n\nQuite good for a really low price Bluetooth earphones.\nOnce you set the Equilizer for your music player, it can sound good. Very worth it for being such a low price.", 'date': datetime.datetime(2023, 11, 18, 17, 20, 39)}, {'username': 'cahyafadzilah', 'comment': 'Performance:Sound very good\nQuality:Good and high quality material\n\nHigh quality with affordable price i got only RM7.++ so cheap and the quality is the best. Gud job Redmi!!!!!', 'date': datetime.datetime(2023, 9, 20, 20, 31, 52)}, {'username': 'syazli', 'comment': "Quality:very good for the price\n\nSounds good. Wouldn't expect it for the price. Money well spent. Postage from china took around a week or so. Only thing is this one doesn't come with a box so it's cheaper.", 'date': datetime.datetime(2024, 2, 1, 19, 37, 33)}, {'username': 'v*****g', 'comment': 'Quality:TERBAIKKKKK\nPerformance:BUNYI BASS KUAT\n\nTERBAIK .. memang sound dia kuat . bass dia pun okay … hargaaa pun murah gilaa . sesuai laaaa harga … boleh cuba cuba beli', 'date': datetime.datetime(2023, 7, 6, 14, 46, 16)}, {'username': 'selva14', 'comment': 'Performance:decent\nQuality:good\n\nNot bad for the prize. Infact it sounds good i just received it so hope the battery life is good. Thank you seller', 'date': datetime.datetime(2024, 2, 24, 16, 46, 9)}, {'username': 'lokmanhakim595', 'comment': 'Performance:no bass yoo, just normal sound\nQuality:good\n\nItem soo soo.\nBut its ok. \nI like it.\nThe price is good. \nVery recomended to buy yoo.\nMust buy.\nI hope it have bass.\nMust improve the sound more yoo.\nDont know the bbatery is full or nil, coz it dont have screen to tell.', 'date': datetime.datetime(2023, 4, 2, 11, 35, 38)}, {'username': 'saifulnizam941', 'comment': 'Quality:tip top\nPerformance:sound dia sedap gila\n\nPenghantaran pantas, berkualiti, ambil masa tak smpai seminggu, boleh beli, murah, mantap, harap tahan lama, terima kasih, kalau rosak nak repeat lagi, okay bye', 'date': datetime.datetime(2024, 3, 4, 2, 24, 32)}, {'username': 'm*****3', 'comment': 'Quality:nice\nPerformance:good\n\nSo far so good,well function too. For this price i didnt expect much anything from this but it does turn out that this product was pretty good actually.The sound was nice. Easy to use too.', 'date': datetime.datetime(2024, 3, 10, 8, 27, 37)}, {'username': 's*****5', 'comment': 'Performance:very good\nQuality:good\n\nBarang dah selamat sampai semalam dahh try guna malam tadi ok semua tak ada apa² masalah,bateri pun macam tahan lama bunyi pun kira sedap la juga harga murah,harap² bertahan lama earpod ni', 'date': datetime.datetime(2024, 2, 3, 10, 5, 21)}, {'username': 'hyuna124', 'comment': 'Performance:Good\nQuality:Ok\n\nEarbuds no problem on both sides.. Medium bass sound.. So far so good.. can accepted and according to price ...

# %%
with open('reviews.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['username', 'comment', 'date']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(reviews)
